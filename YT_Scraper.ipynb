# %% [raw]
# from monkeylearn import MonkeyLearn
# ml = MonkeyLearn('acb42a14d51e14f942c6824e0d41241cd54cca4a')
# model_id = 'cl_pi3C7JiL'
# result = ml.classifiers.classify(model_id, list(data["Comment"].to_json()))

# %%
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from bs4 import BeautifulSoup
import time
import requests
import lxml
import json
import itertools

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Sabarish\anaconda3\python.exe

# %% [raw]
# api key AIzaSyD_gsAPrY1q_JpwQQBBwLntfmwyn3Aiq_A - youtube
# monkeylearn api key - acb42a14d51e14f942c6824e0d41241cd54cca4a

# %%
link = 'https://www.googleapis.com/youtube/v3/search?key=AIzaSyAGg1syggKzB6PtW8DvK6wyCol4UD0yTgw&channelId=UCPg2V8RXeuM3NZ60e-kT7Zw&part=snippet,id&order=date&maxResults=50'
response = requests.get(link).text

temp = json.loads(response)
# print(json.dumps(temp, indent = 2, ensure_ascii = False))

temp1 = temp["items"] #list

Id = []

for i in temp1:
    if i["id"]["kind"] == 'youtube#video':
        Id.append({"id":i["id"]["videoId"]})
        
while True:
    try:
        if temp["nextPageToken"] is None or temp["nextPageToken"] == "":
            break
        else:
            nxtpg = temp["nextPageToken"]
            link = 'https://www.googleapis.com/youtube/v3/search?pageToken='+nxtpg+'&part=snippet&maxResults=25&order=relevance&q=site%3Ayoutube.com&topicId=%2Fm%2F02vx4&key=AIzaSyAGg1syggKzB6PtW8DvK6wyCol4UD0yTgw'
            response = requests.get(link).text

            temp = json.loads(response)
            temp1 = temp["items"]
            for i in temp1:
                if i["id"]["kind"] == 'youtube#video':
                    Id.append({"id":i["id"]["videoId"]})
    except:
        break
    

print(json.dumps(Id, indent = 2, ensure_ascii = False))
p_1d = json.dumps(Id, indent = 2, ensure_ascii = False)
# Out:
# [
#   {
#     "id": "uHhiuzA3o6k"
#   },
#   {
#     "id": "YFcbf6LJ0i8"
#   },
#   {
#     "id": "UOHxpXRu264"
#   },
#   {
#     "id": "pHWCt2IkXmE"
#   },
#   {
#     "id": "gX_e62K7hrM"
#   },
#   {
#     "id": "S--_b6fqy-I"
#   },
#   {
#     "id": "Upy5iEFujgo"
#   },
#   {
#     "id": "kGaYFMBBLHI"
#   },
#   {
#     "id": "JOT7npZCss4"
#   },
#   {
#     "id": "_PZcif6MOBU"
#   },
#   {
#     "id": "A2ToRMgiCnc"
#   },
#   {
#     "id": "utjbE3DAVsI"
#   },
#   {
#     "id": "5DkT-8kVqys"
#   },
#   {
#     "id": "dYeUNdMtBdY"
#   },
#   {
#     "id": "thXEUDyfWto"
#   },
#   {
#     "id": "cCxCDDI9UAs"
#   },
#   {
#     "id": "dqqfvfvrnDk"
#   },
#   {
#     "id": "P_hyzH99TOk"
#   },
#   {
#     "id": "ARpCuC2RBwQ"
#   },
#   {
#     "id": "vWNRkmVjraI"
#   },
#   {
#     "id": "iZnFjbopz9o"
#   },
#   {
#     "id": "ZhVmnxd9fOc"
#   },
#   {
#     "id": "2Vwt4SUhRek"
#   },
#   {
#     "id": "tS6xEeSvjz8"
#   },
#   {
#     "id": "bEwtH02x_is"
#   },
#   {
#     "id": "zM0EP2nkT3E"
#   },
#   {
#     "id": "tO5ZfbDDVY8"
#   },
#   {
#     "id": "h89CCinoX6E"
#   },
#   {
#     "id": "IehKSx2Kmak"
#   },
#   {
#     "id": "a1bzdlvpJe4"
#   },
#   {
#     "id": "9ZwQV0vmLXA"
#   },
#   {
#     "id": "v6IcLOP1OXM"
#   },
#   {
#     "id": "bsY_ECo0bYA"
#   },
#   {
#     "id": "j7ucxBaHLjM"
#   },
#   {
#     "id": "JEp3hy3RqGc"
#   },
#   {
#     "id": "BjNzfTrE6Go"
#   },
#   {
#     "id": "74AKE-m8OWM"
#   },
#   {
#     "id": "cey790sTUkM"
#   },
#   {
#     "id": "3KSQipsuVjg"
#   },
#   {
#     "id": "EFhPCVEYpHM"
#   },
#   {
#     "id": "MxP8BB3bAGE"
#   },
#   {
#     "id": "7osd7I8SjLQ"
#   },
#   {
#     "id": "qu6yRlpBbPo"
#   },
#   {
#     "id": "2q_tA8v5l1Y"
#   },
#   {
#     "id": "ACgrmzoxqaM"
#   },
#   {
#     "id": "7ZncQCU9H6w"
#   },
#   {
#     "id": "ZR08W4_0SBk"
#   },
#   {
#     "id": "sxlFgMVVNuU"
#   },
#   {
#     "id": "ZDMYINfRvTM"
#   },
#   {
#     "id": "8TH7Ela2sKA"
#   },
#   {
#     "id": "pH_G1f6KzfI"
#   },
#   {
#     "id": "64VTm3QWshQ"
#   },
#   {
#     "id": "wLBbwgHm12w"
#   },
#   {
#     "id": "HZ77K_7irGg"
#   },
#   {
#     "id": "Sfu0PgfyCtQ"
#   },
#   {
#     "id": "onL4ObTUr_w"
#   },
#   {
#     "id": "xYGK6lxqAqI"
#   },
#   {
#     "id": "spwiL8uTbPo"
#   },
#   {
#     "id": "b5j6CqbJwlE"
#   },
#   {
#     "id": "gB8BK9eBd7w"
#   },
#   {
#     "id": "bdGYn6CqFMw"
#   },
#   {
#     "id": "A3y6rLgm-3E"
#   },
#   {
#     "id": "Mfmf3JR2Cz8"
#   },
#   {
#     "id": "mLelK1nhtHc"
#   },
#   {
#     "id": "vyVysJk-wKg"
#   },
#   {
#     "id": "DS4dvhDvFsk"
#   },
#   {
#     "id": "YrH-Hky1WI0"
#   },
#   {
#     "id": "D704gNYL5Qk"
#   },
#   {
#     "id": "dwccSyeGn9s"
#   },
#   {
#     "id": "04Q6ybR1bLc"
#   },
#   {
#     "id": "mNA7bT3CLQU"
#   },
#   {
#     "id": "5YHBFGQENDo"
#   },
#   {
#     "id": "xHC8ozrKgRA"
#   },
#   {
#     "id": "UTx2nSbUblk"
#   },
#   {
#     "id": "_7uW_7T92MU"
#   },
#   {
#     "id": "UXwUQmVLzik"
#   },
#   {
#     "id": "WWoqbIDBDbQ"
#   },
#   {
#     "id": "Gi_X98uM-1A"
#   },
#   {
#     "id": "2mh_ZICm-EU"
#   },
#   {
#     "id": "5KKA3by6xEA"
#   },
#   {
#     "id": "34ul43R6UMw"
#   },
#   {
#     "id": "ckyWlU45Cww"
#   },
#   {
#     "id": "zEBmOXsEr6E"
#   },
#   {
#     "id": "JX6PnzmuAJg"
#   },
#   {
#     "id": "ec9AQTk2YzM"
#   },
#   {
#     "id": "naEccnjzLxM"
#   },
#   {
#     "id": "AJfVryno0Ho"
#   },
#   {
#     "id": "ZEBVQ2Y0QiU"
#   },
#   {
#     "id": "jy47SRdcomo"
#   },
#   {
#     "id": "M4ambFr7bdo"
#   },
#   {
#     "id": "YhKVqNZ-HCA"
#   },
#   {
#     "id": "-U1mRkh8nKs"
#   },
#   {
#     "id": "nxMxiLKIEHk"
#   },
#   {
#     "id": "0rtw9uCevMg"
#   },
#   {
#     "id": "dpL5zS-PngE"
#   },
#   {
#     "id": "_TTojY8MihU"
#   },
#   {
#     "id": "flYctEt1OLY"
#   },
#   {
#     "id": "L8taGwfp2sU"
#   },
#   {
#     "id": "cpIwMZ3cUEc"
#   },
#   {
#     "id": "lQQUrbATlhI"
#   },
#   {
#     "id": "2cQBJYK_iTg"
#   },
#   {
#     "id": "P-JBjz-Bzwk"
#   },
#   {
#     "id": "jyfmNXKhhX0"
#   },
#   {
#     "id": "sABVvt0LoHY"
#   },
#   {
#     "id": "tqr9C5F4S6k"
#   },
#   {
#     "id": "__kbC4hzcTo"
#   },
#   {
#     "id": "K6OdnJKt_50"
#   },
#   {
#     "id": "z_5NCE_pe0Q"
#   },
#   {
#     "id": "3p0jAulfDCw"
#   },
#   {
#     "id": "JaqFRHmRwpQ"
#   },
#   {
#     "id": "Lb7fnryhkiY"
#   },
#   {
#     "id": "vFaXDZmlBpc"
#   },
#   {
#     "id": "Sn2Vhp2-xQw"
#   },
#   {
#     "id": "3u0FfNEWCgc"
#   },
#   {
#     "id": "JgZZTW7cx7U"
#   },
#   {
#     "id": "xIcUvrTn7FE"
#   },
#   {
#     "id": "WpgS5P9nCWw"
#   },
#   {
#     "id": "obXNwOhKLEI"
#   },
#   {
#     "id": "iKK5_Ug6w0s"
#   },
#   {
#     "id": "FR2XnmNJ5no"
#   },
#   {
#     "id": "StCG4wUL4-M"
#   },
#   {
#     "id": "HLILbiUqsuo"
#   },
#   {
#     "id": "PMoaKZNOS3U"
#   },
#   {
#     "id": "StCG4wUL4-M"
#   },
#   {
#     "id": "HLILbiUqsuo"
#   },
#   {
#     "id": "PMoaKZNOS3U"
#   },
#   {
#     "id": "48rdiDt_PZs"
#   },
#   {
#     "id": "qsNKYgx6KCg"
#   },
#   {
#     "id": "AbnjSelQYV8"
#   },
#   {
#     "id": "gkGGGtCno_s"
#   },
#   {
#     "id": "FGvD1Vi0WDw"
#   },
#   {
#     "id": "NrRoUK3ZsnU"
#   },
#   {
#     "id": "N-TuSZtyqPY"
#   },
#   {
#     "id": "RcfwcyL01I0"
#   },
#   {
#     "id": "h6BRtAQZfNw"
#   },
#   {
#     "id": "R4GGwDQLbLU"
#   },
#   {
#     "id": "jUUo-m8NksE"
#   },
#   {
#     "id": "9VyYnsCapXw"
#   },
#   {
#     "id": "gNbX_dcENb0"
#   },
#   {
#     "id": "BMFyAijWub4"
#   },
#   {
#     "id": "AtcSnpyJkdo"
#   },
#   {
#     "id": "CXAfTWb42t8"
#   },
#   {
#     "id": "Rm2XKW8YOIE"
#   },
#   {
#     "id": "F60AkbSrD7c"
#   },
#   {
#     "id": "Ud7rgHkTlMI"
#   },
#   {
#     "id": "O-2XxNIEdtA"
#   },
#   {
#     "id": "OiBQwlT2_cE"
#   },
#   {
#     "id": "3HrcsnlkAIU"
#   },
#   {
#     "id": "f6hm1n6JDEQ"
#   },
#   {
#     "id": "TgoNLz2bXVs"
#   },
#   {
#     "id": "SZkiC8YF7ZA"
#   },
#   {
#     "id": "WVKSp2tynPk"
#   },
#   {
#     "id": "dZqUm9TlE-M"
#   },
#   {
#     "id": "geIYxdG0WVQ"
#   },
#   {
#     "id": "3HrcsnlkAIU"
#   },
#   {
#     "id": "HvQ1WrN6AP4"
#   },
#   {
#     "id": "qr53U0H3VPs"
#   },
#   {
#     "id": "D7kJFEAYBOk"
#   },
#   {
#     "id": "0wrqw2mp3lE"
#   },
#   {
#     "id": "Buxnlg1XEUA"
#   },
#   {
#     "id": "5fl248V4tIU"
#   },
#   {
#     "id": "h1UCWxvCByM"
#   },
#   {
#     "id": "AxGJylC6GaI"
#   },
#   {
#     "id": "rDPcEn5TrtI"
#   },
#   {
#     "id": "svgecwH-FCU"
#   },
#   {
#     "id": "yF36cIUml8U"
#   },
#   {
#     "id": "LVHl8c_PT9w"
#   },
#   {
#     "id": "2i1cVk7L3Kw"
#   },
#   {
#     "id": "NP2Bg07dPAs"
#   },
#   {
#     "id": "Wb_K_f6RMg8"
#   },
#   {
#     "id": "nX2-ZOBYJGs"
#   },
#   {
#     "id": "ed_QWwADFdY"
#   },
#   {
#     "id": "uMo-lRYXws0"
#   },
#   {
#     "id": "w_0V0aUseiw"
#   },
#   {
#     "id": "YLUcuP4EOfA"
#   },
#   {
#     "id": "i035oeYT-co"
#   },
#   {
#     "id": "uTCLJ4_i8o0"
#   },
#   {
#     "id": "P-lbWNOmni0"
#   },
#   {
#     "id": "1yPMlA2tbGw"
#   },
#   {
#     "id": "ZnxsSbGvf_E"
#   },
#   {
#     "id": "myI4NEZKYn0"
#   },
#   {
#     "id": "Y9tXV7p-FKs"
#   },
#   {
#     "id": "_uuqsGCiM9I"
#   },
#   {
#     "id": "v2huxDAcQkU"
#   },
#   {
#     "id": "0ygZg54y0wE"
#   },
#   {
#     "id": "TGtACZWU0TQ"
#   },
#   {
#     "id": "WOcSl8F51Jk"
#   },
#   {
#     "id": "CkjVY1oaQRk"
#   },
#   {
#     "id": "zFkw1OO7R34"
#   },
#   {
#     "id": "JKipMJfaf6E"
#   },
#   {
#     "id": "bFwhLObr3VM"
#   },
#   {
#     "id": "oJumRWQf0EU"
#   },
#   {
#     "id": "c-Mk6QWLK_w"
#   },
#   {
#     "id": "H5SMtN6Qa6w"
#   },
#   {
#     "id": "dFLaabgXhpc"
#   },
#   {
#     "id": "1B_7JxGsK7Y"
#   },
#   {
#     "id": "cy7wujlZMMM"
#   },
#   {
#     "id": "7Qyd1IODyJw"
#   },
#   {
#     "id": "7Qyd1IODyJw"
#   },
#   {
#     "id": "rL9JCz7S8Jg"
#   },
#   {
#     "id": "IFwrmDswuG8"
#   },
#   {
#     "id": "fdzY1f2P91k"
#   },
#   {
#     "id": "bOMn4tNS60w"
#   },
#   {
#     "id": "lPJ4HIl26gI"
#   },
#   {
#     "id": "dnOc7zDBtDE"
#   },
#   {
#     "id": "cCZSTGeSuHM"
#   },
#   {
#     "id": "eNq-Q73ilk0"
#   },
#   {
#     "id": "FfM4LDf8UY0"
#   },
#   {
#     "id": "Yu8xamQzuxE"
#   },
#   {
#     "id": "ONWhOD_DGMc"
#   },
#   {
#     "id": "apu2O-fMfJk"
#   },
#   {
#     "id": "SBNSiiMw5FU"
#   },
#   {
#     "id": "yvgU0n0YhPk"
#   },
#   {
#     "id": "gHMSuEMKIIY"
#   },
#   {
#     "id": "tHDf60BNI_c"
#   },
#   {
#     "id": "C57aTE0Bj48"
#   },
#   {
#     "id": "MT5s6JIPi_g"
#   },
#   {
#     "id": "B4bbyHJQ2cc"
#   },
#   {
#     "id": "i1fCccPOihM"
#   },
#   {
#     "id": "ECA0TWir2Zc"
#   },
#   {
#     "id": "5OZVIHqEKd0"
#   },
#   {
#     "id": "FZzmd8pPxvc"
#   },
#   {
#     "id": "BXPc1x4lBDE"
#   },
#   {
#     "id": "i1fCccPOihM"
#   },
#   {
#     "id": "FZzmd8pPxvc"
#   },
#   {
#     "id": "BXPc1x4lBDE"
#   },
#   {
#     "id": "2FE-3A9-If4"
#   },
#   {
#     "id": "tQIJ4kb119Y"
#   },
#   {
#     "id": "q-ZWEYyPVdY"
#   },
#   {
#     "id": "46RrHOsIddY"
#   },
#   {
#     "id": "KTBGPHChKZw"
#   },
#   {
#     "id": "vewB7XreNV8"
#   },
#   {
#     "id": "oF7zOU9fK5g"
#   },
#   {
#     "id": "HS8LV7Z2Fn4"
#   },
#   {
#     "id": "r90NlXsOJqU"
#   },
#   {
#     "id": "2WeYj97O474"
#   },
#   {
#     "id": "DDGVJmuOApM"
#   },
#   {
#     "id": "9b0Y9REZvJk"
#   },
#   {
#     "id": "qUILNHgvk6Q"
#   },
#   {
#     "id": "Y1oGzbidteU"
#   },
#   {
#     "id": "HrD4DoP7ArY"
#   },
#   {
#     "id": "6xkq7bytKVs"
#   },
#   {
#     "id": "6n3BunmIHqY"
#   },
#   {
#     "id": "m-IsK2T45pk"
#   },
#   {
#     "id": "_XgSRYQSzr8"
#   },
#   {
#     "id": "nlz35kP13fI"
#   },
#   {
#     "id": "jSr-4uiEIzI"
#   },
#   {
#     "id": "KKCsbwNTHE0"
#   },
#   {
#     "id": "xi6up6KZmZM"
#   },
#   {
#     "id": "nlz35kP13fI"
#   },
#   {
#     "id": "YzLRWARuLlE"
#   },
#   {
#     "id": "r_lN52VwrBo"
#   },
#   {
#     "id": "qOHKopBdePs"
#   },
#   {
#     "id": "L6svM5Pc55M"
#   },
#   {
#     "id": "jSr-4uiEIzI"
#   },
#   {
#     "id": "5gmFmW1x_7I"
#   },
#   {
#     "id": "68CaQSMU2pU"
#   },
#   {
#     "id": "-MZ74SMZ9sM"
#   },
#   {
#     "id": "XPyDDx8qNAw"
#   },
#   {
#     "id": "mi366hiPam8"
#   },
#   {
#     "id": "Yj1-loNqDCo"
#   },
#   {
#     "id": "8ZrTRJpSruI"
#   },
#   {
#     "id": "fZd2RYn96d4"
#   },
#   {
#     "id": "n69ODVIZgrw"
#   },
#   {
#     "id": "Yi_uWR_gS0M"
#   },
#   {
#     "id": "h_tjv3NmQQ8"
#   },
#   {
#     "id": "C7l9kPHFS4A"
#   },
#   {
#     "id": "muBCvDHn3Sc"
#   },
#   {
#     "id": "CqTlkCFkKNc"
#   },
#   {
#     "id": "TQ_CIbXDxHY"
#   },
#   {
#     "id": "MCvNd4hBK4A"
#   },
#   {
#     "id": "XKz8pKVZfeM"
#   },
#   {
#     "id": "4LLsXXp9Ez8"
#   },
#   {
#     "id": "LRMToPsnnns"
#   },
#   {
#     "id": "Lwy-Xv3DmvA"
#   },
#   {
#     "id": "WFlK9No4F4o"
#   },
#   {
#     "id": "vHxZRk1inZE"
#   },
#   {
#     "id": "hQuG0gcfcIk"
#   },
#   {
#     "id": "i50KJ4qiicM"
#   },
#   {
#     "id": "ioWT-YG5QAE"
#   },
#   {
#     "id": "Fw1zBZC--AY"
#   },
#   {
#     "id": "xSsiS304iY8"
#   },
#   {
#     "id": "Q7GKnUOuaDA"
#   },
#   {
#     "id": "m0QbAow8DTw"
#   },
#   {
#     "id": "sIh0mzHHK40"
#   },
#   {
#     "id": "muX8uHl4UoA"
#   },
#   {
#     "id": "l4ygq-n1w74"
#   },
#   {
#     "id": "rQiLNnWtxmk"
#   },
#   {
#     "id": "_ilAu7fplyc"
#   },
#   {
#     "id": "kZrJbjYERSA"
#   },
#   {
#     "id": "OV6OEEDy1u4"
#   },
#   {
#     "id": "4ls5JeGS8v0"
#   },
#   {
#     "id": "Wuq7IybRKfg"
#   },
#   {
#     "id": "GGbVDihMq90"
#   },
#   {
#     "id": "8BCPfpcW_iA"
#   },
#   {
#     "id": "UoUjz-bOn_w"
#   },
#   {
#     "id": "ss2SJucypX8"
#   },
#   {
#     "id": "t_U2jvVZAh8"
#   },
#   {
#     "id": "ExDzBACaXLg"
#   },
#   {
#     "id": "a9lqAce7nas"
#   },
#   {
#     "id": "t_U2jvVZAh8"
#   },
#   {
#     "id": "oQfdjCcUDoU"
#   },
#   {
#     "id": "lIuts3XMn-Y"
#   },
#   {
#     "id": "VxMcvY6RYx8"
#   },
#   {
#     "id": "XxKLHd1_oVs"
#   },
#   {
#     "id": "HQLOhkdkL1g"
#   },
#   {
#     "id": "Uk2bjk7_ZQo"
#   },
#   {
#     "id": "od-dwl1QCbQ"
#   },
#   {
#     "id": "V1uCjWvjNzo"
#   },
#   {
#     "id": "kzIJsvbP-sM"
#   },
#   {
#     "id": "IYKdqqe7YA0"
#   },
#   {
#     "id": "Xys2qYNeo8I"
#   },
#   {
#     "id": "nMH4WPn9tec"
#   },
#   {
#     "id": "RdYEmivpak0"
#   },
#   {
#     "id": "zyTfeQ-b11s"
#   },
#   {
#     "id": "zEJjRflvjmY"
#   },
#   {
#     "id": "3rpInu4XYM4"
#   },
#   {
#     "id": "W3wACH6HG_0"
#   },
#   {
#     "id": "UMaVynylXmo"
#   },
#   {
#     "id": "0klIbxLBc-w"
#   },
#   {
#     "id": "dIld1-3oT6g"
#   },
#   {
#     "id": "RYSxa6rjxIA"
#   },
#   {
#     "id": "m7mGQc_4n20"
#   },
#   {
#     "id": "dIld1-3oT6g"
#   },
#   {
#     "id": "fc7r_-brzNg"
#   },
#   {
#     "id": "m7mGQc_4n20"
#   },
#   {
#     "id": "UMaVynylXmo"
#   },
#   {
#     "id": "h8XhyvmAq54"
#   },
#   {
#     "id": "V72VlOv5pHw"
#   },
#   {
#     "id": "CfMk3PJ10lo"
#   },
#   {
#     "id": "ZRzRJK2ro40"
#   },
#   {
#     "id": "0fcwmBQloas"
#   },
#   {
#     "id": "UDMuQnlzuys"
#   },
#   {
#     "id": "MdO-9X3IN9w"
#   },
#   {
#     "id": "KbE8jBVwZFM"
#   },
#   {
#     "id": "AyU6pcyqTsk"
#   },
#   {
#     "id": "Q4O_NAVuw50"
#   },
#   {
#     "id": "xLTfw4hb2kY"
#   },
#   {
#     "id": "ECxM0AQhBkw"
#   },
#   {
#     "id": "sfWN8LAgrL0"
#   },
#   {
#     "id": "bZnSD4sgdUU"
#   },
#   {
#     "id": "mpWI1nHkWrc"
#   },
#   {
#     "id": "J3VoAUF4Dec"
#   },
#   {
#     "id": "AQAw7CTgt9w"
#   },
#   {
#     "id": "NMfLJynwyTk"
#   },
#   {
#     "id": "O0VWrDKC1P8"
#   },
#   {
#     "id": "lG_dHQuvHeg"
#   },
#   {
#     "id": "PkRV2G4pC6Y"
#   },
#   {
#     "id": "fqoXYbFi58c"
#   },
#   {
#     "id": "muwccrdKxUc"
#   },
#   {
#     "id": "YTvHKG37cvM"
#   },
#   {
#     "id": "mrO3op8Srrk"
#   },
#   {
#     "id": "gerit_cKr28"
#   },
#   {
#     "id": "I6mZq6FMTNs"
#   },
#   {
#     "id": "9HVsqVYDH0w"
#   },
#   {
#     "id": "qh-yxk-qAOc"
#   },
#   {
#     "id": "bJ6MO_tOp0c"
#   },
#   {
#     "id": "NjfmKB2vkxc"
#   },
#   {
#     "id": "YGX32qmPX_4"
#   },
#   {
#     "id": "wCRY41Qf5JU"
#   },
#   {
#     "id": "J0NX6pHkkYo"
#   },
#   {
#     "id": "Fx503iOdD3I"
#   },
#   {
#     "id": "tzyUHB7ascE"
#   },
#   {
#     "id": "zhTMzZqUAw0"
#   },
#   {
#     "id": "McU5orZU5LM"
#   },
#   {
#     "id": "wHQsxx5FfHc"
#   },
#   {
#     "id": "YxaSj2KWW6E"
#   },
#   {
#     "id": "Ikq1o3ZIxr4"
#   },
#   {
#     "id": "FhKtWTm382g"
#   },
#   {
#     "id": "L-0hkvk1Ky0"
#   },
#   {
#     "id": "OUKGsb8CpF8"
#   },
#   {
#     "id": "l6icCsz3EmA"
#   },
#   {
#     "id": "k39R5HzsnQg"
#   },
#   {
#     "id": "Ikq1o3ZIxr4"
#   },
#   {
#     "id": "De5zXoiHVkg"
#   },
#   {
#     "id": "FhKtWTm382g"
#   },
#   {
#     "id": "L-0hkvk1Ky0"
#   },
#   {
#     "id": "OUKGsb8CpF8"
#   },
#   {
#     "id": "l6icCsz3EmA"
#   },
#   {
#     "id": "k39R5HzsnQg"
#   },
#   {
#     "id": "UO8XWhTLppE"
#   },
#   {
#     "id": "LqMN4zgLI-c"
#   },
#   {
#     "id": "zXfXmi-Jyhs"
#   },
#   {
#     "id": "SclLsRBm9KU"
#   },
#   {
#     "id": "lwue4-Ztf_Q"
#   },
#   {
#     "id": "7gETZ0tRp5o"
#   },
#   {
#     "id": "q8T_duo7uxY"
#   },
#   {
#     "id": "qVLxfWB7VMs"
#   },
#   {
#     "id": "k2AtfFTg340"
#   },
#   {
#     "id": "FwbgGm7_BkY"
#   },
#   {
#     "id": "bKvlWsJBDdA"
#   },
#   {
#     "id": "L5lTMS1soMM"
#   },
#   {
#     "id": "jj2vR6GUtHY"
#   },
#   {
#     "id": "c7WjBRt282w"
#   },
#   {
#     "id": "1CrTuhHJPsI"
#   },
#   {
#     "id": "Q7VmTvgPpz8"
#   },
#   {
#     "id": "yzsNgGmiw68"
#   },
#   {
#     "id": "mAQP5ASH-BA"
#   },
#   {
#     "id": "z7QkpcLUrrA"
#   },
#   {
#     "id": "RNQB4gJSCq0"
#   },
#   {
#     "id": "RLS8J-4UZfE"
#   },
#   {
#     "id": "oK2FsFGw6Mk"
#   },
#   {
#     "id": "DchuxPj6BWI"
#   },
#   {
#     "id": "FndO270QFWo"
#   },
#   {
#     "id": "DAbDN606zNM"
#   },
#   {
#     "id": "vJEr-rSmB4E"
#   },
#   {
#     "id": "KUgJvuZtprQ"
#   },
#   {
#     "id": "MLTqj8qJFIY"
#   },
#   {
#     "id": "iHFJ3w97sWo"
#   },
#   {
#     "id": "aI6LwneWHao"
#   },
#   {
#     "id": "BhDjH-UG-Pg"
#   },
#   {
#     "id": "m9zKNzMKqBQ"
#   },
#   {
#     "id": "1pWO72vqsAI"
#   },
#   {
#     "id": "sqLLdDC5lWc"
#   },
#   {
#     "id": "TWW_BkHa0Cs"
#   },
#   {
#     "id": "APStqdh_A4k"
#   },
#   {
#     "id": "jrvS11LTH0Q"
#   },
#   {
#     "id": "v1dgnmL8WAc"
#   },
#   {
#     "id": "H-NtPquFx1U"
#   },
#   {
#     "id": "M3xMtZSs710"
#   },
#   {
#     "id": "suA2j1RZ_BY"
#   },
#   {
#     "id": "tNNk-Mc1i6k"
#   },
#   {
#     "id": "bCzg2Aiedgw"
#   },
#   {
#     "id": "TnmcMrP-PDk"
#   },
#   {
#     "id": "N2PmtMMVE0I"
#   },
#   {
#     "id": "R55CIqiRL-4"
#   },
#   {
#     "id": "-74cipagBso"
#   },
#   {
#     "id": "wGOpqSixn3E"
#   },
#   {
#     "id": "-MVzbiy4KX4"
#   },
#   {
#     "id": "JAamp2n-170"
#   },
#   {
#     "id": "VC4HxoBZIz8"
#   },
#   {
#     "id": "Zi-lV0yxBpE"
#   },
#   {
#     "id": "AYJZao5oBHI"
#   },
#   {
#     "id": "tagDC9cCBBg"
#   },
#   {
#     "id": "6lpn7z4SMiA"
#   },
#   {
#     "id": "oOexaolfq94"
#   },
#   {
#     "id": "tfW9PIBX7f8"
#   },
#   {
#     "id": "D3F1QRC2NgA"
#   },
#   {
#     "id": "ihUTQHapa-c"
#   },
#   {
#     "id": "tyuK-3dXjoY"
#   },
#   {
#     "id": "TxpUL6pBY5U"
#   },
#   {
#     "id": "hOFAmLOzlrs"
#   },
#   {
#     "id": "SW484HU4KfQ"
#   },
#   {
#     "id": "YE_FjVL_xmk"
#   },
#   {
#     "id": "OrcSUEEmytw"
#   },
#   {
#     "id": "QQfC4LiwWlE"
#   },
#   {
#     "id": "iTvnDC03xLs"
#   },
#   {
#     "id": "uMw9XtANdgA"
#   },
#   {
#     "id": "oOexaolfq94"
#   },
#   {
#     "id": "TxpUL6pBY5U"
#   },
#   {
#     "id": "hOFAmLOzlrs"
#   },
#   {
#     "id": "YE_FjVL_xmk"
#   },
#   {
#     "id": "OrcSUEEmytw"
#   },
#   {
#     "id": "-exfSClefRg"
#   },
#   {
#     "id": "QQfC4LiwWlE"
#   },
#   {
#     "id": "8sI9D313beM"
#   },
#   {
#     "id": "uMw9XtANdgA"
#   },
#   {
#     "id": "UI2Wnl2VawQ"
#   },
#   {
#     "id": "MLGaLmzBnVU"
#   },
#   {
#     "id": "X-gfjQYYoqI"
#   },
#   {
#     "id": "a7BOwi0ikV4"
#   },
#   {
#     "id": "01BV8U9wufQ"
#   },
#   {
#     "id": "v3rH33vBHCo"
#   },
#   {
#     "id": "bQhKjRHFzmQ"
#   },
#   {
#     "id": "tXjXIexUO8g"
#   },
#   {
#     "id": "nuhi-A4SZVM"
#   },
#   {
#     "id": "72S0KkyehAQ"
#   },
#   {
#     "id": "QUuC6hOCfzE"
#   },
#   {
#     "id": "tB4WhKjXN5A"
#   },
#   {
#     "id": "LVgfoYDD6oQ"
#   },
#   {
#     "id": "oBK0_6Bp5ys"
#   },
#   {
#     "id": "pzvyui1Qf7o"
#   },
#   {
#     "id": "LkfO1gUNV2c"
#   },
#   {
#     "id": "hRn1vnkKo-M"
#   },
#   {
#     "id": "x3dGWX-qu78"
#   },
#   {
#     "id": "hoggOfAKcBE"
#   },
#   {
#     "id": "iYDiMo7cDFA"
#   },
#   {
#     "id": "ufTNZWSDR3U"
#   },
#   {
#     "id": "22U9LGDI35Q"
#   },
#   {
#     "id": "cJCZ9guPgJQ"
#   },
#   {
#     "id": "JBEOTM4-fk0"
#   },
#   {
#     "id": "ejDax5reHYw"
#   },
#   {
#     "id": "sJ-mMSWo_H4"
#   },
#  {'id': 'tG_8r8uscSs'},
#  {'id': 'hRn1vnkKo-M'},
#  {'id': '_HTHDRGHDYQ'},
#  {'id': 'Z2MdvjRsRf8'},
#  {'id': 'I4tpw6g0fQg'},
#  {'id': 'ZkakeR2c-j4'},
#  {'id': '-y6KUDQWaIY'},
#  {'id': 'Z29gJZCjNIM'},
#  {'id': 'TrN-fufOllg'},
#  {'id': 'UGofP0YpeK4'},
#  {'id': '8PwYbhPxEAk'},
#  {'id': 'JWq70cvgkYE'}]

# %%
print(Id[2])
# Out:
# {'id': 'UOHxpXRu264'}

# %%
pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Using cached google_api_python_client-2.86.0-py2.py3-none-any.whl (11.3 MB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\sabarish\anaconda3\lib\site-packages (from google-api-python-client) (2.10.1)
# Collecting httplib2<1dev,>=0.15.0
#   Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Collecting uritemplate<5,>=3.0.1
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-auth-httplib2>=0.1.0
#   Using cached google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\users\sabarish\anaconda3\lib\site-packages (from google-api-python-client) (2.6.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\sabarish\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\sabarish\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.56.4)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.20.1 in c:\users\sabarish\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sabarish\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sabarish\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\sabarish\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sabarish\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.7.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sabarish\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sabarish\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sabarish\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sabarish\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sabarish\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sabarish\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)
# Installing collected packages: uritemplate, httplib2, google-auth-httplib2, google-api-python-client
# Successfully installed google-api-python-client-2.86.0 google-auth-httplib2-0.1.0 httplib2-0.22.0 uritemplate-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
api_key = "AIzaSyAGg1syggKzB6PtW8DvK6wyCol4UD0yTgw" # Insert your Api key here.

from googleapiclient.discovery import build
#from google-api-core import discovery
youtube = build('youtube', 'v3', developerKey=api_key)

import pandas as pd

box = [['Name', 'Comment', 'Time', 'Likes', 'Reply Count']]

code_lang = P_Id
# sql_vids = pd.DataFrame([])

for id_code in code_lang:
#     print(id_code)
    def scrape_comments_with_replies():
        data = youtube.commentThreads().list(part='snippet', videoId=id_code['id'], maxResults='100', textFormat="plainText").execute()
        
        for i in data["items"]:
            name = i["snippet"]['topLevelComment']["snippet"]["authorDisplayName"]
            comment = i["snippet"]['topLevelComment']["snippet"]["textDisplay"]
            published_at = i["snippet"]['topLevelComment']["snippet"]['publishedAt']
            likes = i["snippet"]['topLevelComment']["snippet"]['likeCount']
            replies = i["snippet"]['totalReplyCount']
            
            box.append([name, comment, published_at, likes, replies])
            
            totalReplyCount = i["snippet"]['totalReplyCount']
            
            if totalReplyCount > 0:
                
                parent = i["snippet"]['topLevelComment']["id"]
                
                data2 = youtube.comments().list(part='snippet', maxResults='100', parentId=parent,
                                            textFormat="plainText").execute()
                
                for i in data2["items"]:
                    name = i["snippet"]["authorDisplayName"]
                    comment = i["snippet"]["textDisplay"]
                    published_at = i["snippet"]['publishedAt']
                    likes = i["snippet"]['likeCount']
                    replies = ""

                    box.append([name, comment, published_at, likes, replies])

        while ("nextPageToken" in data):
            
            data = youtube.commentThreads().list(part='snippet', videoId=id_code['id'], pageToken=data["nextPageToken"],
                                             maxResults='100', textFormat="plainText").execute()
                                             
            for i in data["items"]:
                name = i["snippet"]['topLevelComment']["snippet"]["authorDisplayName"]
                comment = i["snippet"]['topLevelComment']["snippet"]["textDisplay"]
                published_at = i["snippet"]['topLevelComment']["snippet"]['publishedAt']
                likes = i["snippet"]['topLevelComment']["snippet"]['likeCount']
                replies = i["snippet"]['totalReplyCount']

                box.append([name, comment, published_at, likes, replies])

                totalReplyCount = i["snippet"]['totalReplyCount']

                if totalReplyCount > 0:
                    
                    parent = i["snippet"]['topLevelComment']["id"]

                    data2 = youtube.comments().list(part='snippet', maxResults='100', parentId=parent,
                                                    textFormat="plainText").execute()

                    for i in data2["items"]:
                        name = i["snippet"]["authorDisplayName"]
                        comment = i["snippet"]["textDisplay"]
                        published_at = i["snippet"]['publishedAt']
                        likes = i["snippet"]['likeCount']
                        replies = ''

                        box.append([name, comment, published_at, likes, replies])

        df = pd.DataFrame({'Name': [i[0] for i in box], 'Comment': [i[1] for i in box], 'Time': [i[2] for i in box],
                       'Likes': [i[3] for i in box], 'Reply Count': [i[4] for i in box]})
        
        sql_vids = pd.DataFrame([])

        sql_vids = sql_vids.append(df, ignore_index = True)

        sql_vids.to_csv('youtube-comments.csv', index=False, header=False)
    try:
        scrape_comments_with_replies()
    except:
        continue
data = pd.read_csv(r'youtube-comments.csv',lineterminator='\n')

data
# Out:
# C:\Users\Sabarish\AppData\Local\Temp\ipykernel_3932\4104872982.py:83: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sql_vids = sql_vids.append(df, ignore_index = True)
#                     Name                                            Comment  \
# 0           ELITE GAMER7  Sir i order 2 charging model and i payment it ...
# 1           Vivek Gaming                              How can I contact u ?
# 2              Robocraze   Hello,\nYou can contact us at care@robocraze.com
# 3      black bron gaming  robocraze web site per koi 1000pcs 5mm led nhi...
# 4             LORD ULTRA  Your web site real or fake please tell your se...
# ...                  ...                                                ...
# 30263           Israel B  Finalmente não colocou aquele moleque estranho...
# 30264    Marinava Santos                                    Meu tricolor ❤❤
# 30265     Rodrigo Pontes                                         Fora Ceni!
# 30266    AQUI É TRICOLOR                                       Fora Rogério
# 30267   Fernando Martins                            Chupa anti Rogério Ceni
#
#                        Time  Likes Reply Count\r
# 0      2023-03-11T10:42:39Z      0           0\r
# 1      2023-02-23T17:41:27Z      1           1\r
# 2      2023-03-31T06:03:34Z      0            \r
# 3      2023-01-18T17:18:19Z      0           0\r
# 4      2022-05-11T11:23:36Z      1           1\r
# ...                     ...    ...           ...
# 30263  2023-04-19T02:48:38Z      2           0\r
# 30264  2023-04-19T02:33:11Z      2           0\r
# 30265  2023-04-19T02:32:17Z      1           0\r
# 30266  2023-04-19T02:26:25Z      1           0\r
# 30267  2023-04-19T02:25:57Z      0           0\r
#
# [30268 rows x 5 columns]

# %%
data = pd.read_csv(r'youtube-comments.csv',lineterminator='\n')

data
# Out:
#                     Name                                            Comment  \
# 0           ELITE GAMER7  Sir i order 2 charging model and i payment it ...
# 1           Vivek Gaming                              How can I contact u ?
# 2              Robocraze   Hello,\nYou can contact us at care@robocraze.com
# 3      black bron gaming  robocraze web site per koi 1000pcs 5mm led nhi...
# 4             LORD ULTRA  Your web site real or fake please tell your se...
# ...                  ...                                                ...
# 30263           Israel B  Finalmente não colocou aquele moleque estranho...
# 30264    Marinava Santos                                    Meu tricolor ❤❤
# 30265     Rodrigo Pontes                                         Fora Ceni!
# 30266    AQUI É TRICOLOR                                       Fora Rogério
# 30267   Fernando Martins                            Chupa anti Rogério Ceni
#
#                        Time  Likes Reply Count\r
# 0      2023-03-11T10:42:39Z      0           0\r
# 1      2023-02-23T17:41:27Z      1           1\r
# 2      2023-03-31T06:03:34Z      0            \r
# 3      2023-01-18T17:18:19Z      0           0\r
# 4      2022-05-11T11:23:36Z      1           1\r
# ...                     ...    ...           ...
# 30263  2023-04-19T02:48:38Z      2           0\r
# 30264  2023-04-19T02:33:11Z      2           0\r
# 30265  2023-04-19T02:32:17Z      1           0\r
# 30266  2023-04-19T02:26:25Z      1           0\r
# 30267  2023-04-19T02:25:57Z      0           0\r
#
# [30268 rows x 5 columns]

# %%
data = data[0:3000]

data
# Out:
#                        Name  \
# 0              ELITE GAMER7
# 1              Vivek Gaming
# 2                 Robocraze
# 3         black bron gaming
# 4                LORD ULTRA
# ...                     ...
# 2995           Tria Lets Go
# 2996      Shooting star RED
# 2997               Rashid P
# 2998  Mohammad Syawal Nento
# 2999          пожилая жабка
#
#                                                 Comment                  Time  \
# 0     Sir i order 2 charging model and i payment it ...  2023-03-11T10:42:39Z
# 1                                 How can I contact u ?  2023-02-23T17:41:27Z
# 2      Hello,\nYou can contact us at care@robocraze.com  2023-03-31T06:03:34Z
# 3     robocraze web site per koi 1000pcs 5mm led nhi...  2023-01-18T17:18:19Z
# 4     Your web site real or fake please tell your se...  2022-05-11T11:23:36Z
# ...                                                 ...                   ...
# 2995  In the other match, lazio was lost.  This seas...  2020-07-05T06:39:09Z
# 2996                               Amazing performance.  2020-07-05T06:37:54Z
# 2997  That second goal from torino had crossed the line  2020-07-05T06:37:40Z
# 2998                                            Offside  2020-07-05T06:50:03Z
# 2999  Хотите шутку? Колобок повесился ,смешно? Если ...  2020-07-05T06:37:37Z
#
#       Likes Reply Count\r
# 0         0           0\r
# 1         1           1\r
# 2         0            \r
# 3         0           0\r
# 4         1           1\r
# ...     ...           ...
# 2995      0           0\r
# 2996      0           0\r
# 2997      0           1\r
# 2998      0            \r
# 2999      0           0\r
#
# [3000 rows x 5 columns]

# %%
def cleanTxt(text):
    text = re.sub(r'[^\w]', ' ', text)
    return text

# %%
#data['Comment'] = data['Comment'].apply(cleanTxt)
for _ in range(10):
    data['Comment'][_] = cleanTxt(data['Comment'][_])
#print(cleanTxt(data['Comment'][1]))
# Out:
# C:\Users\Sabarish\AppData\Local\Temp\ipykernel_3932\95125159.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Comment'][_] = cleanTxt(data['Comment'][_])

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# get polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

#Columns
data['Subjectivity'] = data['Comment'].apply(getSubjectivity) 
data['Polarity'] = data['Comment'].apply(getPolarity)

data
# Out:
# C:\Users\Sabarish\AppData\Local\Temp\ipykernel_3932\805509601.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Subjectivity'] = data['Comment'].apply(getSubjectivity)
# C:\Users\Sabarish\AppData\Local\Temp\ipykernel_3932\805509601.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Polarity'] = data['Comment'].apply(getPolarity)
#                        Name  \
# 0              ELITE GAMER7
# 1              Vivek Gaming
# 2                 Robocraze
# 3         black bron gaming
# 4                LORD ULTRA
# ...                     ...
# 2995           Tria Lets Go
# 2996      Shooting star RED
# 2997               Rashid P
# 2998  Mohammad Syawal Nento
# 2999          пожилая жабка
#
#                                                 Comment                  Time  \
# 0     Sir i order 2 charging model and i payment it ...  2023-03-11T10:42:39Z
# 1                                 How can I contact u    2023-02-23T17:41:27Z
# 2       Hello  You can contact us at care robocraze com  2023-03-31T06:03:34Z
# 3     robocraze web site per koi 1000pcs 5mm led nhi...  2023-01-18T17:18:19Z
# 4     Your web site real or fake please tell your se...  2022-05-11T11:23:36Z
# ...                                                 ...                   ...
# 2995  In the other match, lazio was lost.  This seas...  2020-07-05T06:39:09Z
# 2996                               Amazing performance.  2020-07-05T06:37:54Z
# 2997  That second goal from torino had crossed the line  2020-07-05T06:37:40Z
# 2998                                            Offside  2020-07-05T06:50:03Z
# 2999  Хотите шутку? Колобок повесился ,смешно? Если ...  2020-07-05T06:37:37Z
#
#       Likes Reply Count\r  Subjectivity  Polarity
# 0         0           0\r         0.000     0.000
# 1         1           1\r         0.000     0.000
# 2         0            \r         0.000     0.000
# 3         0           0\r         0.500    -0.500
# 4         1           1\r         1.000    -0.750
# ...     ...           ...           ...       ...
# 2995      0           0\r         0.375    -0.125
# 2996      0           0\r         0.900     0.600
# 2997      0           1\r         0.000     0.000
# 2998      0            \r         0.000     0.000
# 2999      0           0\r         0.000     0.000
#
# [3000 rows x 7 columns]

# %%
# allWords = ' '.join( [cmts for cmts in data['Comment']])
# wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allWords)

# %%
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score > 0:
        return 'Positive'
    else:
        return 'Neutral'
    
data['TextBlob Analysis'] = data['Polarity'].apply(getAnalysis)
# Out:
# C:\Users\Sabarish\AppData\Local\Temp\ipykernel_3932\4065931384.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TextBlob Analysis'] = data['Polarity'].apply(getAnalysis)

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 685.6 kB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sabarish\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\sabarish\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 753.1 kB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in c:\users\sabarish\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in c:\users\sabarish\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sabarish\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sabarish\anaconda3\lib\site-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ------------------------------------ 200.1/200.1 kB 759.6 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\sabarish\anaconda3\lib\site-packages (from transformers) (1.22.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sabarish\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sabarish\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\sabarish\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sabarish\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sabarish\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sabarish\anaconda3\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sabarish\anaconda3\lib\site-packages (from requests->transformers) (1.26.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some layers from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english were not used when initializing TFDistilBertForSequenceClassification: ['dropout_19']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english and are newly initialized: ['dropout_39']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
text = data["Comment"]
text
ans = []
for i in text:
    j = classifier(i)
    #print(i,j[0]["label"])
    ans.append(j[0]["label"])
data['HuggingFace Analysis'] = ans
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (807 > 512). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [70], in <cell line: 4>()
#       3 ans = []
#       4 for i in text:
# ----> 5     j = classifier(i)
#       6     #print(i,j[0]["label"])
#       7     ans.append(j[0]["label"])
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\text_classification.py:155, in TextClassificationPipeline.__call__(self, *args, **kwargs)
#     121 def __call__(self, *args, **kwargs):
#     122     """
#     123     Classify the text(s) given as inputs.
#     124
#    (...)
#     153         If `top_k` is used, one such dictionary is returned per label.
#     154     """
# --> 155     result = super().__call__(*args, **kwargs)
#     156     # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     157     _legacy = "top_k" not in kwargs
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\base.py:1109, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1101     return next(
#    1102         iter(
#    1103             self.get_iterator(
#    (...)
#    1106         )
#    1107     )
#    1108 else:
# -> 1109     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\base.py:1116, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1114 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1115     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1116     model_outputs = self.forward(model_inputs, **forward_params)
#    1117     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1118     return outputs
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\base.py:1010, in Pipeline.forward(self, model_inputs, **forward_params)
#    1008 if self.framework == "tf":
#    1009     model_inputs["training"] = False
# -> 1010     model_outputs = self._forward(model_inputs, **forward_params)
#    1011 elif self.framework == "pt":
#    1012     inference_context = self.get_inference_context()
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\text_classification.py:182, in TextClassificationPipeline._forward(self, model_inputs)
#     181 def _forward(self, model_inputs):
# --> 182     return self.model(**model_inputs)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\lib\site-packages\transformers\modeling_tf_utils.py:433, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     430     config = self.config
#     432 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 433 return func(self, **unpacked_inputs)
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_tf_distilbert.py:753, in TFDistilBertForSequenceClassification.call(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, labels, training)
#     728 @unpack_inputs
#     729 @add_start_docstrings_to_model_forward(DISTILBERT_INPUTS_DOCSTRING.format("batch_size, sequence_length"))
#     730 @add_code_sample_docstrings(
#    (...)
#     745     training: Optional[bool] = False,
#     746 ) -> Union[TFSequenceClassifierOutput, Tuple[tf.Tensor]]:
#     747     r"""
#     748     labels (`tf.Tensor` of shape `(batch_size,)`, *optional*):
#     749         Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     750         config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     751         `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     752     """
# --> 753     distilbert_output = self.distilbert(
#     754         input_ids=input_ids,
#     755         attention_mask=attention_mask,
#     756         head_mask=head_mask,
#     757         inputs_embeds=inputs_embeds,
#     758         output_attentions=output_attentions,
#     759         output_hidden_states=output_hidden_states,
#     760         return_dict=return_dict,
#     761         training=training,
#     762     )
#     763     hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     764     pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~\anaconda3\lib\site-packages\transformers\modeling_tf_utils.py:433, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     430     config = self.config
#     432 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 433 return func(self, **unpacked_inputs)
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_tf_distilbert.py:409, in TFDistilBertMainLayer.call(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, training)
#     406 else:
#     407     head_mask = [None] * self.num_hidden_layers
# --> 409 embedding_output = self.embeddings(input_ids, inputs_embeds=inputs_embeds)  # (bs, seq_length, dim)
#     410 tfmr_output = self.transformer(
#     411     embedding_output,
#     412     attention_mask,
#    (...)
#     417     training=training,
#     418 )
#     420 return tfmr_output
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_tf_distilbert.py:129, in TFEmbeddings.call(self, input_ids, position_ids, inputs_embeds, training)
#     126 if position_ids is None:
#     127     position_ids = tf.expand_dims(tf.range(start=0, limit=input_shape[-1]), axis=0)
# --> 129 position_embeds = tf.gather(params=self.position_embeddings, indices=position_ids)
#     130 final_embeddings = inputs_embeds + position_embeds
#     131 final_embeddings = self.LayerNorm(inputs=final_embeddings)
#
# InvalidArgumentError: Exception encountered when calling layer "embeddings" (type TFEmbeddings).
#
# indices[0,512] = 512 is not in [0, 512) [Op:ResourceGather]
#
# Call arguments received by layer "embeddings" (type TFEmbeddings):
#   • input_ids=tf.Tensor(shape=(1, 807), dtype=int32)
#   • position_ids=None
#   • inputs_embeds=None
#   • training=False

# %%
data
# Out:
#                        Name  \
# 0              ELITE GAMER7
# 1              Vivek Gaming
# 2                 Robocraze
# 3         black bron gaming
# 4                LORD ULTRA
# ...                     ...
# 2995           Tria Lets Go
# 2996      Shooting star RED
# 2997               Rashid P
# 2998  Mohammad Syawal Nento
# 2999          пожилая жабка
#
#                                                 Comment                  Time  \
# 0     Sir i order 2 charging model and i payment it ...  2023-03-11T10:42:39Z
# 1                                 How can I contact u    2023-02-23T17:41:27Z
# 2       Hello  You can contact us at care robocraze com  2023-03-31T06:03:34Z
# 3     robocraze web site per koi 1000pcs 5mm led nhi...  2023-01-18T17:18:19Z
# 4     Your web site real or fake please tell your se...  2022-05-11T11:23:36Z
# ...                                                 ...                   ...
# 2995  In the other match, lazio was lost.  This seas...  2020-07-05T06:39:09Z
# 2996                               Amazing performance.  2020-07-05T06:37:54Z
# 2997  That second goal from torino had crossed the line  2020-07-05T06:37:40Z
# 2998                                            Offside  2020-07-05T06:50:03Z
# 2999  Хотите шутку? Колобок повесился ,смешно? Если ...  2020-07-05T06:37:37Z
#
#       Likes Reply Count\r  Subjectivity  Polarity TextBlob Analysis
# 0         0           0\r         0.000     0.000           Neutral
# 1         1           1\r         0.000     0.000           Neutral
# 2         0            \r         0.000     0.000           Neutral
# 3         0           0\r         0.500    -0.500          Negative
# 4         1           1\r         1.000    -0.750          Negative
# ...     ...           ...           ...       ...               ...
# 2995      0           0\r         0.375    -0.125          Negative
# 2996      0           0\r         0.900     0.600          Positive
# 2997      0           1\r         0.000     0.000           Neutral
# 2998      0            \r         0.000     0.000           Neutral
# 2999      0           0\r         0.000     0.000           Neutral
#
# [3000 rows x 8 columns]

# %%
data["TextBlob Analysis"]=data["TextBlob Analysis"].str.capitalize()
#data["HuggingFace Analysis"] = data["HuggingFace Analysis"].str.capitalize()
# Out:
# C:\Users\Sabarish\AppData\Local\Temp\ipykernel_3932\3428676316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["TextBlob Analysis"]=data["TextBlob Analysis"].str.capitalize()

# %%
data["TextBlob Analysis"].value_counts()
# Out:
# Neutral     1991
# Positive     875
# Negative     134
# Name: TextBlob Analysis, dtype: int64

# %%
data["HuggingFace Analysis"].value_counts()
# Out:
# Positive    150
# Negative     76
# Name: HuggingFace Analysis, dtype: int64

# %% [raw]
# c = 0
# for (i,j) in zip(data["TextBlob Analysis"],data["HuggingFace Analysis"]):
#     if i != j:
#         c+=1
#
# c

# %% [raw]
# text = data["Comments"]
#
# for i in len(text):
#     for j in range(i,len(text)):
